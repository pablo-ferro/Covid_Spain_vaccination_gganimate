# %%
#Sample of visualizations

# %%
# https://www.eldiario.es/sociedad/tasa-incidencia-alcanza-nivel-agosto-ano-pasado-casos-100-000-habitantes_1_7973441.html

# %%
#file site https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov/vacunaCovid19.htm

# %%
# excelfile https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov/documentos/Informe_Comunicacion_20210527.ods

# %%
import urllib.request
url = 'https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov/documentos/Informe_Comunicacion_20210527.ods'
urllib.request.urlretrieve(url, '/Users/pablofernandezrodriguez/Desktop/pythoncourse/2021/5/Covid_ES/updatedfile.ods')
# Out:
# ('/Users/pablofernandezrodriguez/Desktop/pythoncourse/2021/5/Covid_ES/updatedfile.ods',
#  <http.client.HTTPMessage at 0x7fb0f4f8d400>)

# %%
import pandas as pd

# %%
#conda install pandas-ods-reader

# %%
#pip install pandas_ods_reader

# %%
from pandas_ods_reader import read_ods

# %%
base_path = "/Users/pablofernandezrodriguez/Desktop/pythoncourse/2021/5/Covid_ES/updatedfile.ods"
sheet_index = 1
df = read_ods(base_path , sheet_index )

# %%
df
# Out:
#              unnamed.1  Dosis entregadas Pfizer (1)  \
# 0            Andalucía                    2919240.0
# 1               Aragón                     567765.0
# 2            Asturias                      520385.0
# 3             Baleares                     340830.0
# 4             Canarias                     710160.0
# 5            Cantabria                     252285.0
# 6     Castilla y Leon                     1218855.0
# 7   Castilla La Mancha                     797805.0
# 8             Cataluña                    2853080.0
# 9        C. Valenciana                    1783270.0
# 10         Extremadura                     459305.0
# 11             Galicia                    1280095.0
# 12            La Rioja                     133445.0
# 13              Madrid                    2357475.0
# 14             Murcia                      504995.0
# 15             Navarra                     255795.0
# 16          País Vasco                     925290.0
# ...

# %%
df.sample(10)
# Out:
#              unnamed.1  Dosis entregadas Pfizer (1)  \
# 3             Baleares                     340830.0
# 18             Melilla                      24210.0
# 12            La Rioja                     133445.0
# 5            Cantabria                     252285.0
# 9        C. Valenciana                    1783270.0
# 1               Aragón                     567765.0
# 7   Castilla La Mancha                     797805.0
# 6     Castilla y Leon                     1218855.0
# 17               Ceuta                      24210.0
# 11             Galicia                    1280095.0
#
#     Dosis entregadas Moderna (1)  Dosis entregadas AstraZeneca (1)  \
# 3                        54800.0                          145800.0
# 18                        3700.0                           11000.0
# 12                       19500.0                           39600.0
# 5                        36900.0                           72500.0
# ...
